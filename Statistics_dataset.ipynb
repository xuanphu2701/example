# %%
import pandas as pd
import numpy as np
from glob import glob
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Doc dataset va them cot domain

domains = []
file_list = glob("*.xlsx")
df = pd.DataFrame()
for i in range(len(file_list)):
  data = pd.read_excel(file_list[i])
  domain = re.findall(r'cmt_(.*).xlsx', file_list[i])
  domains.append(domain[0])
  data['domain'] = [domain[0] for i in range(len(data))]
  df = pd.concat([df, data], axis = 'index')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 788064 entries, 0 to 60967
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   788064 non-null  int64
#  1   tittle_item  788064 non-null  object
#  2   comment      786865 non-null  object
#  3   rating_star  788064 non-null  int64
#  4   domain       788064 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 36.1+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  ...       domain
# 0           0  ...  ThoiTrangNu
# 1           1  ...  ThoiTrangNu
# 2           2  ...  ThoiTrangNu
# 3           3  ...  ThoiTrangNu
# 4           4  ...  ThoiTrangNu
#
# [5 rows x 5 columns]

# %%
#Phan tich domain
df['domain'].value_counts()
# Out:
# Voucher_DichVu           63956
# ChamSocThuCung           60968
# GiatGiu_ChamSocNhaCua    58522
# DoChoi                   53637
# ThoiTrangTreEm           50050
# BaLo_TuiViNam            47225
# NhaSachOnline            43503
# Oto_XeMay_XeDap          39904
# MayAnh_MayQuayPhim       37645
# BachHoaOnline            36912
# SacDep                   34458
# TheThao_DuLich           33330
# MayTinh_Laptop           29140
# PhuKien_TrangSucNu       28796
# NhaCua_DoiSong           25700
# ThietBiDienGiaDung       23459
# ThietBiDienTu            21469
# TuiVi_Nu                 19487
# Me_Be                    17520
# GiayDep_Nam              14644
# DienThoai_PhuKien        14550
# ThoiTrangNu               9609
# GiayDep_Nu                9411
# ThoiTrangNam              5199
# SucKhoe                   4658
# DongHo                    4312
# Name: domain, dtype: int64

# %%
sns.set()
plt.figure(figsize = (10, 10))
ax = sns.countplot(x = 'domain', data = df)
plt.setp(ax.get_xticklabels(), rotation= 90)
plt.show()

# %%
#Phan tich rating
df['rating_star'].value_counts()
# Out:
# 5    291909
# 4    215203
# 3    136207
# 1     83853
# 2     60892
# Name: rating_star, dtype: int64

# %%
sns.set()
plt.figure(figsize = (10, 10))
sns.countplot(x = 'rating_star', data = df)
